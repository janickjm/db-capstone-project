# %%
# !pip install mysql-connector-python
# Out:
# Collecting mysql-connector-python
#   Downloading mysql_connector_python-9.5.0-cp313-cp313-macosx_14_0_arm64.whl.metadata (7.5 kB)
# Downloading mysql_connector_python-9.5.0-cp313-cp313-macosx_14_0_arm64.whl (17.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.6/17.6 MB 22.9 MB/s  0:00:009.2 MB/s eta 0:00:0101
# Installing collected packages: mysql-connector-python
# Successfully installed mysql-connector-python-9.5.0

# %%
import mysql.connector as connector

# %%
connection = connector.connect(user = "admin2", password = "ZtU7B*TojAXC", db = "LittleLemonDB")

# %%
show_tables_query = "SHOW tables"

# %%
cursor = connection.cursor()

# %%
cursor.execute(show_tables_query)

# %%
results = cursor.fetchall()
print(results)
# Out:
# [('Booking',), ('Clients',), ('Menu',), ('MenuItems',), ('OrderDelivery',), ('Orders',), ('ordersview',), ('Roles',), ('Staff',), ('Status',)]

# %%
join_query= """
SELECT  a.ClientID, 
  CONCAT(a.FirstName, ' ', a.LastName) AS FullName
FROM Clients AS a
INNER JOIN Booking AS b ON a.ClientID = b.ClientID
INNER JOIN Orders AS o ON b.BookingID = o.BookingID
WHERE o.Total > 60; 

"""

# %%
cursor.execute(join_query)
var = cursor.column_names

# %%
print(var)
results = cursor.fetchall()
for result in results:
    print(result)
# Out:
# ('ClientID', 'FullName')
# (1, 'Anna Iversen')
# (3, 'Vanessa McCarthy')
# (1, 'Anna Iversen')
